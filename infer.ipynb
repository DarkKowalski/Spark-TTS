# %%
from cli.SparkTTS import SparkTTS
from IPython.display import Audio

# %%
tts = SparkTTS("./pretrained_models/Spark-TTS-0.5B/")

# %%
wav = tts.inference("Hello how's it going?", "./example/prompt_audio.wav")

# %%
Audio(wav, rate=16000)
